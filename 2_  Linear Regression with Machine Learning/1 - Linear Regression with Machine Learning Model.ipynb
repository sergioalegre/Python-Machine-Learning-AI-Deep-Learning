# %%
#https://www.eduonix.com/dashboard/complete-guide-to-machine-learning-using-python/lecture/16108019
#https://www.eduonix.com/dashboard/complete-guide-to-machine-learning-using-python/lecture/16108020

import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn import linear_model
from sklearn.model_selection import train_test_split

diabetes = datasets.load_diabetes() # Call the diabetes dataset from sklearn

df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names) # load the dataset as a pandas data frame


### One Feature
features=["bmi"]

x = df[features]
y = diabetes.target # define the target variable (dependent variable) as y


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# print(x_train)

lm = linear_model.LinearRegression() #sin parametros, asi que todo por defecto


model = lm.fit(x_train,y_train)
predictions = lm.predict(x_test)

fit = np.polyfit(x["bmi"],y,1)
fit_fn = np.poly1d(fit)
print(fit_fn)


fig, ax = plt.subplots()
plt.plot(x["bmi"],y,'ro') #ro son 'red dots'
plt.plot(x["bmi"], fit_fn(x["bmi"]), '--k') # --k es linea punteada negra
plt.plot(x_test,predictions,'bo') #predicciones como bo son 'blue dots'
plt.xlabel('BMI')
plt.ylabel('Score')
ax.grid()
plt.show()


slope, intercept, r_value, p_value, std_err = stats.linregress(x["bmi"],y)
# print("The r-value is: ",r_value)
# print("The p-value is: ",p_value)
print(std_err)

pred = lm.predict(x)
sq = np.sum((y - list(pred)) ** 2)

print(np.sqrt(sq / len(x)))


#Resultado: nos da la funcion: 949.4 x + 152.1
# Out:
#
# 949.4 x + 152.1
# The r-value is:  0.5864501344746886
# The p-value is:  3.4660064451673e-42
# 62.51512200284676
# 62.39841420712021

# %%
#https://www.eduonix.com/dashboard/complete-guide-to-machine-learning-using-python/lecture/16108020
from sklearn import datasets
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split

diabetes = datasets.load_diabetes() # Call the diabetes dataset from sklearn

df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names) # load the dataset as a pandas data frame



### Multiple Features
features=list(df)

x = df[features]
y = diabetes.target # define the target variable (dependent variable) as y

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)
lm = linear_model.LinearRegression()


model = lm.fit(x_train,y_train)
predictions = lm.predict(x_test)

# fit = np.polyfit(x["bmi"],y,1)
# fit_fn = np.poly1d(fit)
# print(fit_fn)


fig, ax = plt.subplots()
plt.plot(x_train, y_train, 'ro')
plt.plot(x_test,predictions,'bo')
plt.xlabel('Features')
plt.ylabel('Score')
ax.grid()
plt.show()
